# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots

# %%
#load data set from excel
data=pd.read_excel("Copy of final.xlsx")
data
# Out:
#                 State  Debt-to-GDP (%) in FY 2023-24  \
# 0   Arunachal Pradesh                           53.0
# 1              Punjab                           46.8
# 2            Nagaland                           41.6
# 3             Manipur                           40.0
# 4           Meghalaya                           39.9
# 5    Himachal Pradesh                           39.0
# 6               Bihar                           35.7
# 7             Mizoram                           37.8
# 8         West Bengal                           37.1
# 9           Rajasthan                           36.8
# 10             Kerala                           36.6
# 11     Andhra Pradesh                           33.3
# 12                Goa                           32.2
# 13      Uttar Pradesh                           31.7
# 14             Sikkim                           31.5
# 15     Madhya Pradesh                           30.4
# 16        Uttarakhand                           28.2
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of                 State  Debt-to-GDP (%) in FY 2023-24  \
# 0   Arunachal Pradesh                           53.0
# 1              Punjab                           46.8
# 2            Nagaland                           41.6
# 3             Manipur                           40.0
# 4           Meghalaya                           39.9
# 5    Himachal Pradesh                           39.0
# 6               Bihar                           35.7
# 7             Mizoram                           37.8
# 8         West Bengal                           37.1
# 9           Rajasthan                           36.8
# 10             Kerala                           36.6
# 11     Andhra Pradesh                           33.3
# 12                Goa                           32.2
# 13      Uttar Pradesh                           31.7
# 14             Sikkim                           31.5
# 15     Madhya Pradesh                           30.4
# ...

# %%
# null values in dataset
data.isnull()
# Out:
#     State  Debt-to-GDP (%) in FY 2023-24  GSDP(RS-Lakh crore)(FY 2023-2024)  \
# 0   False                          False                              False
# 1   False                          False                              False
# 2   False                          False                              False
# 3   False                          False                              False
# 4   False                          False                              False
# 5   False                          False                              False
# 6   False                          False                              False
# 7   False                          False                              False
# 8   False                          False                              False
# 9   False                          False                              False
# 10  False                          False                              False
# ...

# %%
# null values of column in dataset 
data.isnull().sum()
# Out:
# State                                     0
# Debt-to-GDP (%) in FY 2023-24             0
# GSDP(RS-Lakh crore)(FY 2023-2024)         0
# Debt Till 2023/Crores                     6
# Debt release in 2024                      0
# Total Debt in 2019-2020                   0
# Total Debt in 2020-2021                   0
# Total Debt in 2021-2022                  10
# Total Debt in 2022-2023                   7
#  % Population below poverty line 2023     0
# Average Literacy Rate % 2023              0
# Total Population 2023 lakhs/ crores       0
# Agriculture  2015-16                      0
# 2016-17                                   8
# 2017-18                                  13
# dtype: int64

# %%
#Size of dataset
data.shape[0]
# Out:
# 27

# %%
# null percentage value of columns  in dataset
data.isnull().sum()/data.shape[0]*100
# Out:
# State                                     0.000000
# Debt-to-GDP (%) in FY 2023-24             0.000000
# GSDP(RS-Lakh crore)(FY 2023-2024)         0.000000
# Debt Till 2023/Crores                    22.222222
# Debt release in 2024                      0.000000
# Total Debt in 2019-2020                   0.000000
# Total Debt in 2020-2021                   0.000000
# Total Debt in 2021-2022                  37.037037
# Total Debt in 2022-2023                  25.925926
#  % Population below poverty line 2023     0.000000
# Average Literacy Rate % 2023              0.000000
# Total Population 2023 lakhs/ crores       0.000000
# Agriculture  2015-16                      0.000000
# 2016-17                                  29.629630
# 2017-18                                  48.148148
# dtype: float64

# %%
# check the data
data.isnull().sum()/data.shape[0]*100
# Out:
# State                                     0.000000
# Debt-to-GDP (%) in FY 2023-24             0.000000
# GSDP(RS-Lakh crore)(FY 2023-2024)         0.000000
# Debt Till 2023/Crores                    22.222222
# Debt release in 2024                      0.000000
# Total Debt in 2019-2020                   0.000000
# Total Debt in 2020-2021                   0.000000
# Total Debt in 2021-2022                  37.037037
# Total Debt in 2022-2023                  25.925926
#  % Population below poverty line 2023     0.000000
# Average Literacy Rate % 2023              0.000000
# Total Population 2023 lakhs/ crores       0.000000
# Agriculture  2015-16                      0.000000
# 2016-17                                  29.629630
# 2017-18                                  48.148148
# dtype: float64

# %%
data
# Out:
#                 State  Debt-to-GDP (%) in FY 2023-24  \
# 0   Arunachal Pradesh                           53.0
# 1              Punjab                           46.8
# 2            Nagaland                           41.6
# 3             Manipur                           40.0
# 4           Meghalaya                           39.9
# 5    Himachal Pradesh                           39.0
# 6               Bihar                           35.7
# 7             Mizoram                           37.8
# 8         West Bengal                           37.1
# 9           Rajasthan                           36.8
# 10             Kerala                           36.6
# 11     Andhra Pradesh                           33.3
# 12                Goa                           32.2
# 13      Uttar Pradesh                           31.7
# 14             Sikkim                           31.5
# 15     Madhya Pradesh                           30.4
# 16        Uttarakhand                           28.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   State                                  27 non-null     object
#  1   Debt-to-GDP (%) in FY 2023-24          27 non-null     float64
#  2   GSDP(RS-Lakh crore)(FY 2023-2024)      27 non-null     float64
#  3   Debt Till 2023/Crores                  21 non-null     float64
#  4   Debt release in 2024                   27 non-null     int64
#  5   Total Debt in 2019-2020                27 non-null     int64
#  6   Total Debt in 2020-2021                27 non-null     int64
#  7   Total Debt in 2021-2022                17 non-null     float64
#  8   Total Debt in 2022-2023                20 non-null     float64
#  9    % Population below poverty line 2023  27 non-null     float64
# ...

# %%
data.describe()
# Out:
#        Debt-to-GDP (%) in FY 2023-24  GSDP(RS-Lakh crore)(FY 2023-2024)  \
# count                      27.000000                          27.000000
# mean                       31.574074                          10.358889
# std                         9.300686                          10.473484
# min                        13.100000                           0.350000
# 25%                        25.250000                           1.570000
# 50%                        31.700000                           6.980000
# 75%                        37.450000                          15.095000
# max                        53.000000                          38.790000
#
#        Debt Till 2023/Crores  Debt release in 2024  Total Debt in 2019-2020  \
# count              21.000000             27.000000             2.700000e+01
# mean           361129.619048           5226.185185             6.426598e+05
# std            226840.544184           5455.536433             6.174768e+05
# ...

# %%
#Add a column of dept in 2020-2022 
data['Total Debt in 2019-2023']=data['Total Debt in 2019-2020']+data['Total Debt in 2020-2021']+data['Total Debt in 2021-2022']+data['Total Debt in 2022-2023']
data.tail()
# Out:
#           State  Debt-to-GDP (%) in FY 2023-24  \
# 22  Chattisgarh                           25.0
# 23    Karnataka                           23.0
# 24  Maharashtra                           18.2
# 25      Gujarat                           15.3
# 26       Odisha                           13.1
#
#     GSDP(RS-Lakh crore)(FY 2023-2024)  Debt Till 2023/Crores  \
# 22                               5.07                    NaN
# 23                              25.00               535157.0
# 24                              38.79               680357.0
# 25                              25.62               423711.0
# 26                               8.65               113856.0
#
#     Debt release in 2024  Total Debt in 2019-2020  Total Debt in 2020-2021  \
# 22                  4842                   307995                   312532
# 23                  5183                  1467522                  1575400
# 24                  8978                  2408482                  2393953
# ...

# %%
#remove the column of  total dept in 2019-2020,2020-2021,2021-2022,2022-2023
data.drop(["Total Debt in 2019-2020","Total Debt in 2020-2021","Total Debt in 2021-2022","Total Debt in 2022-2023"],inplace=True,axis=1)

# %%
data
# Out:
#                 State  Debt-to-GDP (%) in FY 2023-24  \
# 0   Arunachal Pradesh                           53.0
# 1              Punjab                           46.8
# 2            Nagaland                           41.6
# 3             Manipur                           40.0
# 4           Meghalaya                           39.9
# 5    Himachal Pradesh                           39.0
# 6               Bihar                           35.7
# 7             Mizoram                           37.8
# 8         West Bengal                           37.1
# 9           Rajasthan                           36.8
# 10             Kerala                           36.6
# 11     Andhra Pradesh                           33.3
# 12                Goa                           32.2
# 13      Uttar Pradesh                           31.7
# 14             Sikkim                           31.5
# 15     Madhya Pradesh                           30.4
# 16        Uttarakhand                           28.2
# ...

# %%
statewise = pd.pivot_table(data,values =[" % Population below poverty line 2023", "Average Literacy Rate % 2023", "Total Population 2023 lakhs/ crores"],index="State",aggfunc=max)

# %%
statewise["population of poverty"] = statewise[" % Population below poverty line 2023"] * statewise["Total Population 2023 lakhs/ crores"].astype(float) / 100

# %%
statewise["population of litracy"] = statewise["Average Literacy Rate % 2023"] * statewise["Total Population 2023 lakhs/ crores"].astype(float) / 100

# %%
statewise =statewise.sort_values(by="Total Population 2023 lakhs/ crores", ascending=False)

# %%
statewise.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_b2230_row0_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_b2230_row0_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_b2230_row0_col2, #T_b2230_row0_col3, #T_b2230_row0_col4, #T_b2230_row1_col0, #T_b2230_row13_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b2230_row1_col1, #T_b2230_row7_col3, #T_b2230_row10_col3, #T_b2230_row13_col2, #T_b2230_row14_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_b2230_row1_col2, #T_b2230_row7_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_b2230_row1_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_b2230_row1_col4 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_b2230_row2_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_b2230_row2_col1 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_b2230_row2_col2 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# ...

# %%
top_10_Total_Population_2023_lakhs_crores = data.groupby(by='State').max()[['Total Population 2023 lakhs/ crores']].sort_values(by=['Total Population 2023 lakhs/ crores'], ascending=False).reset_index()

# %%
fig=plt.figure(figsize=(16,9))

# %%
plt.title("Top 10 states with most population states in india",size=25)
# Out:
# Text(0.5, 1.0, 'Top 10 states with most population states in india')

# %%
ax=sns.barplot(data=top_10_Total_Population_2023_lakhs_crores.iloc[:10],y="Total Population 2023 lakhs/ crores",x="State",linewidth=2,edgecolor='red')

# %%
#top state population
top_10_Total_Population_2023_lakhs_crores = data.groupby(by='State').max()[['Total Population 2023 lakhs/ crores']].sort_values(by=['Total Population 2023 lakhs/ crores'], ascending=False).reset_index()
fig=plt.figure(figsize=(16,9))
plt.title("Top 10 states with most population states in india",size=25)
ax=sns.barplot(data=top_10_Total_Population_2023_lakhs_crores.iloc[:10],y="Total Population 2023 lakhs/ crores",x="State",linewidth=2,edgecolor='red')
plt.xlabel("States")
plt.ylabel("Total Population 2023 lakhs/ crores")
plt.show()

# %%
#top state poverty rate
top_10_Total_Population_2023_lakhs_crores = data.groupby(by='State').max()[[' % Population below poverty line 2023']].sort_values(by=[' % Population below poverty line 2023'], ascending=False).reset_index()
fig=plt.figure(figsize=(12,6))
plt.title("Top 10 states with most poverty rate in india",size=25)
ax=sns.barplot(data=top_10_Total_Population_2023_lakhs_crores.iloc[:10],y=" % Population below poverty line 2023",x="State",linewidth=2,edgecolor='red')
plt.xlabel("States")
plt.ylabel("% Population below poverty line 2023")
plt.show()

# %%
#Average Literacy Rate % 2023
top_10_Total_Population_2023_lakhs_crores = data.groupby(by='State').max()[['Average Literacy Rate % 2023']].sort_values(by=['Average Literacy Rate % 2023'], ascending=False).reset_index()
fig=plt.figure(figsize=(14,7))
plt.title("Top 10 states with most Average Literacy Rate in india",size=25)
ax=sns.barplot(data=top_10_Total_Population_2023_lakhs_crores.iloc[:10],y="Average Literacy Rate % 2023",x="State",linewidth=2,edgecolor='red')
plt.xlabel("States")
plt.ylabel("Average Literacy Rate % 2023")
plt.show()

# %%
#Average Dept release in 2024
top_10_Total_Population_2023_lakhs_crores = data.groupby(by='State').max()[['Debt release in 2024']].sort_values(by=['Debt release in 2024'], ascending=False).reset_index()
fig=plt.figure(figsize=(14,7))
plt.title("Top 10 states with most Debt release in 2024 from Central government of india",size=25)
ax=sns.barplot(data=top_10_Total_Population_2023_lakhs_crores.iloc[:10],y="Debt release in 2024",x="State",linewidth=2,edgecolor='red')
plt.xlabel("States")
plt.ylabel("Debt release in 2024 in crore")
plt.show()

# %%
# Debt Till 2023/Crores
top_10_Total_Population_2023_lakhs_crores = data.groupby(by='State').max()[['Debt Till 2023/Crores']].sort_values(by=['Debt Till 2023/Crores'], ascending=False).reset_index()
fig=plt.figure(figsize=(14,7))
plt.title("Top 10 states with most Debt till 2023 ",size=25)
ax=sns.barplot(data=top_10_Total_Population_2023_lakhs_crores.iloc[:10],y="Debt Till 2023/Crores",x="State",linewidth=2,edgecolor='red')
plt.xlabel("States")
plt.ylabel("Debt Till 2023/Crores")
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=data[data['State'].isin(['Uttar Pradesh', 'Tamil Nadu', 'Maharashtra', 'West Bengal', 'Kerala'])], x='Debt-to-GDP (%) in FY 2023-24', y='Total Population 2023 lakhs/ crores', hue='State')
ax.set_title("Top 5 high population States of India", size=16)
# Out:
# Text(0.5, 1.0, 'Top 5 high population States of India')

# %%
data['Total Agriculture Land till 2018']=data['Agriculture  2015-16']+data['2016-17']+data['2017-18']
data.tail()
# Out:
#           State  Debt-to-GDP (%) in FY 2023-24  \
# 22  Chattisgarh                           25.0
# 23    Karnataka                           23.0
# 24  Maharashtra                           18.2
# 25      Gujarat                           15.3
# 26       Odisha                           13.1
#
#     GSDP(RS-Lakh crore)(FY 2023-2024)  Debt Till 2023/Crores  \
# 22                               5.07                    NaN
# 23                              25.00               535157.0
# 24                              38.79               680357.0
# 25                              25.62               423711.0
# 26                               8.65               113856.0
#
#     Debt release in 2024   % Population below poverty line 2023  \
# 22                  4842                                  39.03
# 23                  5183                                  13.20
# 24                  8978                                  14.85
# ...

# %%
# remove the column of  total agriculture land of 2015-2016,2016-2017,2017-2018
data.drop(["Agriculture  2015-16","2016-17","2017-18"],inplace=True,axis=1)

# %%
data
# Out:
#                 State  Debt-to-GDP (%) in FY 2023-24  \
# 0   Arunachal Pradesh                           53.0
# 1              Punjab                           46.8
# 2            Nagaland                           41.6
# 3             Manipur                           40.0
# 4           Meghalaya                           39.9
# 5    Himachal Pradesh                           39.0
# 6               Bihar                           35.7
# 7             Mizoram                           37.8
# 8         West Bengal                           37.1
# 9           Rajasthan                           36.8
# 10             Kerala                           36.6
# 11     Andhra Pradesh                           33.3
# 12                Goa                           32.2
# 13      Uttar Pradesh                           31.7
# 14             Sikkim                           31.5
# 15     Madhya Pradesh                           30.4
# 16        Uttarakhand                           28.2
# ...

# %%
# Total Agriculture Land
top_10_Total_Population_2023_lakhs_crores = data.groupby(by='State').max()[['Total Agriculture Land till 2018']].sort_values(by=['Total Agriculture Land till 2018'], ascending=False).reset_index()
fig=plt.figure(figsize=(14,7))
plt.title("Top 10 Agriculture Land states till 2018 ",size=25)
ax=sns.barplot(data=top_10_Total_Population_2023_lakhs_crores.iloc[:10],y="Total Agriculture Land till 2018",x="State",linewidth=2,edgecolor='red')
plt.xlabel("States")
plt.ylabel("Total Agriculture Land till 2018")
plt.show()

# %%
# Most Total Agriculture Land till 2018 States
max_states = data.groupby('State')['Total Agriculture Land till 2018'].sum().to_frame('Total Agriculture Land till 2018')
max_states = max_states.sort_values('Total Agriculture Land till 2018', ascending = False)[:5]
max_states
# Out:
#                 Total Agriculture Land till 2018
# State
# Rajasthan                                54096.0
# Madhya Pradesh                           45568.0
# Karnataka                                29756.0
# Andhra Pradesh                           18334.0
# West Bengal                              15736.0

# %%
# Least Total Agriculture Land till 2018 States
max_states = data.groupby('State')['Total Agriculture Land till 2018'].sum().to_frame('Total Agriculture Land till 2018')
max_states = max_states.sort_values('Total Agriculture Land till 2018', ascending = True)[:5]
max_states
# Out:
#              Total Agriculture Land till 2018
# State
#  Manipur                                  0.0
# Mizoram                                   0.0
# Maharashtra                               0.0
# Kerala                                    0.0
# Tamil Nadu                                0.0

# %%
# Sort the DataFrame by the 'Debt-to-GDP (%) in FY 2023-24' column
max_states = data.groupby('State')['Debt-to-GDP (%) in FY 2023-24'].sum().to_frame('Debt-to-GDP (%) in FY 2023-24')
max_states = max_states.sort_values('Debt-to-GDP (%) in FY 2023-24', ascending=False)[:5]
max_states
# Out:
#                    Debt-to-GDP (%) in FY 2023-24
# State
# Arunachal Pradesh                           53.0
# Punjab                                      46.8
# Nagaland                                    41.6
#  Manipur                                    40.0
# Meghalaya                                   39.9

# %%
# Sort the DataFrame by the 'Debt-to-GDP (%) in FY 2023-24' column
max_states = data.groupby('State')['Debt-to-GDP (%) in FY 2023-24'].sum().to_frame('Debt-to-GDP (%) in FY 2023-24')
max_states = max_states.sort_values('Debt-to-GDP (%) in FY 2023-24', ascending=True)[:5]
max_states
# Out:
#              Debt-to-GDP (%) in FY 2023-24
# State
# Odisha                                13.1
# Gujarat                               15.3
# Maharashtra                           18.2
# Karnataka                             23.0
# Telangana                             23.8

# %%
# Most Total Population 2023 lakhs/ crores States
max_states = data.groupby('State')['Total Population 2023 lakhs/ crores'].sum().to_frame('Total Population 2023 lakhs/ crores')
max_states = max_states.sort_values('Total Population 2023 lakhs/ crores', ascending = False)[:5]
max_states
# Out:
#                 Total Population 2023 lakhs/ crores
# State
# Uttar Pradesh                             235687000
# Bihar                                     126756000
# Maharashtra                               126385000
# West Bengal                                99084000
# Madhya Pradesh                             86579000

# %%
# Least Total Population 2023 lakhs/ crores States
max_states = data.groupby('State')['Total Population 2023 lakhs/ crores'].sum().to_frame('Total Population 2023 lakhs/ crores')
max_states = max_states.sort_values('Total Population 2023 lakhs/ crores', ascending = True)[:5]
max_states
# Out:
#                    Total Population 2023 lakhs/ crores
# State
# Sikkim                                          689000
# Uttarakhand                                    1163700
# Mizoram                                        1238000
# Arunachal Pradesh                              1562000
# Goa                                            1575000

# %%
# MostTotal Debt in 2019-2023  States
max_states = data.groupby('State')['Total Debt in 2019-2023'].sum().to_frame('Total Debt in 2019-2023')
max_states = max_states.sort_values('Total Debt in 2019-2023', ascending = False)[:5]
max_states
# Out:
#                 Total Debt in 2019-2023
# State
# Uttar Pradesh                5245227.00
# Tamil Nadu                   5115281.00
# Rajasthan                    3428246.00
# Andhra Pradesh               2887217.00
# Kerala                       2509774.96

# %%
# Least Total Debt in 2019-2023  States
max_states = data.groupby('State')['Total Debt in 2019-2023'].sum().to_frame('Total Debt in 2019-2023')
max_states = max_states.sort_values('Total Debt in 2019-2023', ascending = True)[:5]
max_states
# Out:
#            Total Debt in 2019-2023
# State
#  Manipur                       0.0
# Telangana                      0.0
# Sikkim                         0.0
# Nagaland                       0.0
# Mizoram                        0.0

# %%
# MostTotal Average Literacy Rate % 2023  States
max_states = data.groupby('State')['Average Literacy Rate % 2023'].sum().to_frame('Average Literacy Rate % 2023')
max_states = max_states.sort_values('Average Literacy Rate % 2023', ascending = False)[:5]
max_states
# Out:
#                   Average Literacy Rate % 2023
# State
# Kerala                                   96.20
# Mizoram                                  91.58
# Uttarakhand                              87.60
# Goa                                      87.40
# Himachal Pradesh                         86.60

# %%
# Least Total Average Literacy Rate % 2023 States
max_states = data.groupby('State')['Average Literacy Rate % 2023'].sum().to_frame('Average Literacy Rate % 2023')
max_states = max_states.sort_values('Average Literacy Rate % 2023', ascending = True)[:5]
max_states
# Out:
#                    Average Literacy Rate % 2023
# State
# Andhra Pradesh                            66.40
# Arunachal Pradesh                         66.95
# Rajasthan                                 69.70
# Bihar                                     70.90
# Telangana                                 72.80

# %%
# Most% Population below poverty line 2023 States
max_states = data.groupby('State')[' % Population below poverty line 2023'].sum().to_frame(' % Population below poverty line 2023')
max_states = max_states.sort_values(' % Population below poverty line 2023', ascending = False)[:5]
max_states
# Out:
#                 % Population below poverty line 2023
# State
# Bihar                                          51.91
# Jharkhand                                      42.16
# Chattisgarh                                    39.03
# Uttar Pradesh                                  37.79
#  Manipur                                       36.89

# %%
# Least Total Average Literacy Rate % 2023 States
max_states = data.groupby('State')[' % Population below poverty line 2023'].sum().to_frame(' % Population below poverty line 2023')
max_states = max_states.sort_values(' % Population below poverty line 2023', ascending = True)[:5]
max_states
# Out:
#              % Population below poverty line 2023
# State
# Kerala                                       0.71
# Goa                                          3.76
# Sikkim                                       3.82
# Tamil Nadu                                   4.89
# Punjab                                       5.59

# %%
#load data set from excel
data=pd.read_csv("crop_yield.csv")
data
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...
